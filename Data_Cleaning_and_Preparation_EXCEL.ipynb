# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedhitha-e/240901070-PYTHON/blob/main/Data_Cleaning_and_Preparation_EXCEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option('display.max_columns',10)
print("Original data:\n")
df=pd.read_excel("studentsmark.xlsx")
print(df)
# Out:
# Original data:
#
#    Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Bio  Tamil
# 0           0     1          Aja   95     96   99   98   96     92
# 1           1     2        Bison   95     96   58   68   82     25
# 2           2     3          Cat   63     45   99   98   51     38
# 3           3     4         Dany    9     85   99   56   89     45
# 4           4     5        Eliza    6     78   99   58   64     67
# 5           5     6         Fijo   95     96   99   59   73     92
# 6           6     7         Gani   94     45   99    2   85     87
# 7           7     8         Hari   95     96   99    8   96     92
# 8           8     9        Iniya   58     59   99   98   34     78
# 9           9    10         Jack   95     96   99   98   96     59

# %%
f=df['Student Name'].str.strip()
f.to_excel("studentsmark.xlsx")

print("\nReplace value:")
k=df.ffill()
print(k)
print("\nUpdated list\n")
k.to_excel("studentsmark.xlsx")
# Out:
# Replace value:
#    Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Bio  Tamil
# 0           0     1          Aja   95     96   99   98   96     92
# 1           1     2        Bison   95     96   58   68   82     25
# 2           2     3          Cat   63     45   99   98   51     38
# 3           3     4         Dany    9     85   99   56   89     45
# 4           4     5        Eliza    6     78   99   58   64     67
# 5           5     6         Fijo   95     96   99   59   73     92
# 6           6     7         Gani   94     45   99    2   85     87
# 7           7     8         Hari   95     96   99    8   96     92
# 8           8     9        Iniya   58     59   99   98   34     78
# 9           9    10         Jack   95     96   99   98   96     59
#
# Updated list

# %%
print("\nDrop one particular column and its values:\n")
k.drop(['Bio'],axis=1,inplace=True)
print(k)
print("\nUpdated list..\n")
k.to_excel("studentsmark.xlsx")
# Out:
# Drop one particular column and its values:
#
#    Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Tamil
# 0           0     1          Aja   95     96   99   98     92
# 1           1     2        Bison   95     96   58   68     25
# 2           2     3          Cat   63     45   99   98     38
# 3           3     4         Dany    9     85   99   56     45
# 4           4     5        Eliza    6     78   99   58     67
# 5           5     6         Fijo   95     96   99   59     92
# 6           6     7         Gani   94     45   99    2     87
# 7           7     8         Hari   95     96   99    8     92
# 8           8     9        Iniya   58     59   99   98     78
# 9           9    10         Jack   95     96   99   98     59
#
# Updated list..

# %%
print("\nDrop NaN rows:\n")
df=pd.read_excel("studentsmark.xlsx")
print(df)
x=df.dropna()
print(x)
print("\nUpdated data list:\n")
x.to_excel("studentsmark.xlsx")
# Out:
# Drop NaN rows:
#
#    Unnamed: 0.1  Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Tamil
# 0             0           0     1          Aja   95     96   99   98     92
# 1             1           1     2        Bison   95     96   58   68     25
# 2             2           2     3          Cat   63     45   99   98     38
# 3             3           3     4         Dany    9     85   99   56     45
# 4             4           4     5        Eliza    6     78   99   58     67
# 5             5           5     6         Fijo   95     96   99   59     92
# 6             6           6     7         Gani   94     45   99    2     87
# 7             7           7     8         Hari   95     96   99    8     92
# 8             8           8     9        Iniya   58     59   99   98     78
# 9             9           9    10         Jack   95     96   99   98     59
#    Unnamed: 0.1  Unnamed: 0  S.No Student Name  Eng  Maths  Phy  Che  Tamil
# 0             0           0     1          Aja   95     96   99   98     92
# 1             1           1     2        Bison   95     96   58   68     25
# 2             2           2     3          Cat   63     45   99   98     38
# 3             3           3     4         Dany    9     85   99   56     45
# 4             4           4     5        Eliza    6     78   99   58     67
# 5             5           5     6         Fijo   95     96   99   59     92
# 6             6           6     7         Gani   94     45   99    2     87
# 7             7           7     8         Hari   95     96   99    8     92
# 8             8           8     9        Iniya   58     59   99   98     78
# 9             9           9    10         Jack   95     96   99   98     59
#
# Updated data list:

# %%
print("\nReplace values:\n")
n=pd.read_excel("studentsmark.xlsx")
print("\nOriginal data:\n")
print(n)
y=n.replace({89:88})
print("\nReplaced dataset:\n")
print(y)
print("\nUpdated dataset:\n")
y.to_excel("studentsmark.xlsx")
# Out:
# Replace values:
#
#
# Original data:
#
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  S.No Student Name  Eng  Maths  Phy  \
# 0             0             0           0     1          Aja   95     96   99
# 1             1             1           1     2        Bison   95     96   58
# 2             2             2           2     3          Cat   63     45   99
# 3             3             3           3     4         Dany    9     85   99
# 4             4             4           4     5        Eliza    6     78   99
# 5             5             5           5     6         Fijo   95     96   99
# 6             6             6           6     7         Gani   94     45   99
# 7             7             7           7     8         Hari   95     96   99
# 8             8             8           8     9        Iniya   58     59   99
# 9             9             9           9    10         Jack   95     96   99
#
#    Che  Tamil
# 0   98     92
# 1   68     25
# 2   98     38
# 3   56     45
# 4   58     67
# 5   59     92
# 6    2     87
# 7    8     92
# 8   98     78
# 9   98     59
#
# Replaced dataset:
#
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  S.No Student Name  Eng  Maths  Phy  \
# 0             0             0           0     1          Aja   95     96   99
# 1             1             1           1     2        Bison   95     96   58
# 2             2             2           2     3          Cat   63     45   99
# 3             3             3           3     4         Dany    9     85   99
# 4             4             4           4     5        Eliza    6     78   99
# 5             5             5           5     6         Fijo   95     96   99
# 6             6             6           6     7         Gani   94     45   99
# 7             7             7           7     8         Hari   95     96   99
# 8             8             8           8     9        Iniya   58     59   99
# 9             9             9           9    10         Jack   95     96   99
#
#    Che  Tamil
# 0   98     92
# 1   68     25
# 2   98     38
# 3   56     45
# 4   58     67
# 5   59     92
# 6    2     87
# 7    8     92
# 8   98     78
# 9   98     59
#
# Updated dataset:

# %%
df=pd.read_excel("studentsmark.xlsx")
print(df)
print("\nExtract using isin() function:\n")
new=df['Eng'].isin([95])
print(df[new])
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  S.No  ... Eng  Maths  \
# 0             0             0             0           0     1  ...  95     96
# 1             1             1             1           1     2  ...  95     96
# 2             2             2             2           2     3  ...  63     45
# 3             3             3             3           3     4  ...   9     85
# 4             4             4             4           4     5  ...   6     78
# 5             5             5             5           5     6  ...  95     96
# 6             6             6             6           6     7  ...  94     45
# 7             7             7             7           7     8  ...  95     96
# 8             8             8             8           8     9  ...  58     59
# 9             9             9             9           9    10  ...  95     96
#
#    Phy  Che  Tamil
# 0   99   98     92
# 1   58   68     25
# 2   99   98     38
# 3   99   56     45
# 4   99   58     67
# 5   99   59     92
# 6   99    2     87
# 7   99    8     92
# 8   99   98     78
# 9   99   98     59
#
# [10 rows x 11 columns]
#
# Extract using isin() function:
#
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  S.No  ... Eng  Maths  \
# 0             0             0             0           0     1  ...  95     96
# 1             1             1             1           1     2  ...  95     96
# 5             5             5             5           5     6  ...  95     96
# 7             7             7             7           7     8  ...  95     96
# 9             9             9             9           9    10  ...  95     96
#
#    Phy  Che  Tamil
# 0   99   98     92
# 1   58   68     25
# 5   99   59     92
# 7   99    8     92
# 9   99   98     59
#
# [5 rows x 11 columns]
