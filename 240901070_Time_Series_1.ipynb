# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedhitha-e/240901070-PYTHON/blob/main/240901070_Time_Series_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
a=datetime.datetime.now()
print("Today-now function: ",a)
# Out:
# Today-now function:  2026-04-16 02:51:26.175240

# %%
today=datetime.datetime.today()
print("\nToday: ",today)
# Out:
# Today:  2026-04-16 02:51:49.612518

# %%
tomorrow=today+datetime.timedelta(days=3)
print("\nTomorrow:",tomorrow)
# Out:
# Tomorrow: 2026-04-19 02:51:49.612518

# %%
yesterday=today-datetime.timedelta(days=2)
print("\nYesterday: ",yesterday)
# Out:
# Yesterday:  2026-04-14 02:51:49.612518

# %%
a=datetime.datetime.now()
b=datetime.datetime(2020,6,8,23,10,25,404040)
print("\nDate format [2020,6,8,23,10,25,404040): ",b)
# Out:
# Date format [2020,6,8,23,10,25,404040):  2020-06-08 23:10:25.404040

# %%
from datetime import date
d=date(2024, 12, 31)
print("\nReplacing date",d,d.replace(day=15))
# Out:
# Replacing date 2024-12-31 2024-12-15

# %%
t=date(2004,4,17)
d=date(2004,4,17).ctime()
print("\nDay and Month:",t,d)
# Out:
# Day and Month: 2004-04-17 Sat Apr 17 00:00:00 2004

# %%
today=date.today()
print("\nToday:",today)
print("Current year:", today.year)
print("Current month:", today.month)
print("Current day:",today.day)
# Out:
# Today: 2026-04-16
# Current year: 2026
# Current month: 4
# Current day: 16
