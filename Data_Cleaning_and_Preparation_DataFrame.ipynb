# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedhitha-e/240901070-PYTHON/blob/main/Data_Cleaning_and_Preparation_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'], columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("Dropped DataFrame with NaN\n",df)
print("\n")
# Out:
# Original DataFrame with NaN
#          one       two     three
# a -0.451307  0.026071 -0.845251
# b       NaN       NaN       NaN
# c -1.134603 -0.274521  0.590720
# d  1.138755  0.540008 -0.389687
# e       NaN       NaN       NaN
# f -0.353756  1.049258 -0.744702
#
#
# Dropped DataFrame with NaN
#          one       two     three
# a -0.451307  0.026071 -0.845251
# b       NaN       NaN       NaN
# c -1.134603 -0.274521  0.590720
# d  1.138755  0.540008 -0.389687
# e       NaN       NaN       NaN
# f -0.353756  1.049258 -0.744702

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'], columns=['one','two','three'])
df=df.reindex(['a','b','c'])
print("Original DataFrame with NaN\n",df)
print("\n")
print("NaN replaced with '0'\n",df.fillna(0))
# Out:
# Original DataFrame with NaN
#          one       two     three
# a  0.001195  1.897810 -1.613711
# b       NaN       NaN       NaN
# c -0.780715 -1.447823  1.007681
#
#
# NaN replaced with '0'
#          one       two     three
# a  0.001195  1.897810 -1.613711
# b  0.000000  0.000000  0.000000
# c -0.780715 -1.447823  1.007681

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original DataFrame\n",df)
print("\nDataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original DataFrame
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
# DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'], columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNaN-with true fill:\n")
print(df['one'].isnull())
# Out:
# Original DataFrame:
#          one       two     three
# a -1.455527  0.213961 -1.445606
# b       NaN       NaN       NaN
# c -0.030526 -0.873593 -1.064416
# d  0.328554  0.197728  0.948832
# e       NaN       NaN       NaN
# f -1.475138  0.483822 -0.157049
#
# NaN-with true fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'], columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("Original DataFrame:\n",df)
print("\nNaN-Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original DataFrame:
#          one       two     three
# a  0.953351  0.674494  1.228191
# b       NaN       NaN       NaN
# c -0.006384 -1.500404 -1.220789
# d -0.237054  1.177681 -0.412583
# e       NaN       NaN       NaN
# f  0.091527  1.384250 -0.361333
#
# NaN-Filled with Background values:
#
#         one       two     three
# a  0.953351  0.674494  1.228191
# b -0.006384 -1.500404 -1.220789
# c -0.006384 -1.500404 -1.220789
# d -0.237054  1.177681 -0.412583
# e  0.091527  1.384250 -0.361333
# f  0.091527  1.384250 -0.361333
# /tmp/ipykernel_271/2806269380.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
