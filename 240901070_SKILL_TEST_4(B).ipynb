# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedhitha-e/240901070-PYTHON/blob/main/240901070_SKILL_TEST_4(B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Problem Statement:
You are given a dictionary containing information about products in an inventory, including
their names, prices, and quantities available:
data = {'Product': ['Laptop', 'Smartphone', 'Tablet', 'Monitor', 'Keyboard'],'Price': [1200, 800,
300, 150, 50],'Quantity': [10, 20, 15, 25, 50]} and do any five basic operations and plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Given dictionary
data = {
    'Product': ['Laptop', 'Smartphone', 'Tablet', 'Monitor', 'Keyboard'],
    'Price': [1200, 800, 300, 150, 50],
    'Quantity': [10, 20, 15, 25, 50]
}

# Convert dictionary to DataFrame
df = pd.DataFrame(data)

print("Inventory Data:\n", df)

# Operation 1: Calculate total inventory value
df['Total_Value'] = df['Price'] * df['Quantity']
print("\nTotal Value of Each Product:\n")
print(df[['Product','Total_Value']])

# Operation 2: Average price
avg_price = df['Price'].mean()
print("\nAverage Price:", avg_price)

# Operation 3: Maximum price product
max_price_product = df.loc[df['Price'].idxmax()]
print("\nProduct with Maximum Price:\n", max_price_product)

# Operation 4: Minimum price product
min_price_product = df.loc[df['Price'].idxmin()]
print("\nProduct with Minimum Price:\n", min_price_product)

# Operation 5: Total quantity of products
total_quantity = df['Quantity'].sum()
print("\nTotal Quantity of All Products:", total_quantity)

# Plot: Price of products
plt.bar(df['Product'], df['Price'])
plt.title("Product Price Comparison")
plt.xlabel("Product")
plt.ylabel("Price")
plt.show()
# Out:
# Inventory Data:
#        Product  Price  Quantity
# 0      Laptop   1200        10
# 1  Smartphone    800        20
# 2      Tablet    300        15
# 3     Monitor    150        25
# 4    Keyboard     50        50
#
# Total Value of Each Product:
#
#       Product  Total_Value
# 0      Laptop        12000
# 1  Smartphone        16000
# 2      Tablet         4500
# 3     Monitor         3750
# 4    Keyboard         2500
#
# Average Price: 500.0
#
# Product with Maximum Price:
#  Product        Laptop
# Price            1200
# Quantity           10
# Total_Value     12000
# Name: 0, dtype: object
#
# Product with Minimum Price:
#  Product        Keyboard
# Price                50
# Quantity             50
# Total_Value        2500
# Name: 4, dtype: object
#
# Total Quantity of All Products: 120
