# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedhitha-e/240901070-PYTHON/blob/main/240901070_Time_Series_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

#create a date variable that contains the dates
dates = [datetime(2011, 1, 2),
datetime(2011, 1, 5),
datetime(2011, 1, 7),
datetime(2011, 1, 8),
datetime(2011, 1, 10),
datetime(2011, 1, 12)]

#with this date object, create a series
ts = pd.Series(np.random.randn(6), index=dates)
print("Date Index \n",ts)
# Out:
# Date Index
#  2011-01-02    1.072110
# 2011-01-05   -0.013365
# 2011-01-07    1.728126
# 2011-01-08    0.301899
# 2011-01-10    1.351346
# 2011-01-12    0.910376
# dtype: float64

# %%
print("\nDate Index alone from the series: \n",ts.index)
# Out:
# Date Index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[2]
print("\nSecond index:\n", stamp)
# Out:
# Second index:
#  2011-01-07 00:00:00

# %%
#play like a ball with long-times series
longer_ts=pd.Series(np.random.randn(1000),
index=pd.date_range("2000-01-01",periods=1000))
print("\nDaterange up to 1000 days:\n",longer_ts)
# Out:
# Daterange up to 1000 days:
#  2000-01-01   -0.547025
# 2000-01-02    0.531503
# 2000-01-03   -1.113049
# 2000-01-04   -0.652512
# 2000-01-05   -0.310414
#                 ...
# 2002-09-22   -0.419925
# 2002-09-23   -1.493236
# 2002-09-24    2.031439
# 2002-09-25    1.378456
# 2002-09-26   -1.348827
# Freq: D, Length: 1000, dtype: float64

# %%
print("\nDate range-2001 year:\n", longer_ts["2001"])
# Out:
# Date range-2001 year:
#  2001-01-01    0.011677
# 2001-01-02   -0.385545
# 2001-01-03    0.106011
# 2001-01-04    0.204291
# 2001-01-05   -2.129339
#                 ...
# 2001-12-27   -1.034712
# 2001-12-28   -1.009251
# 2001-12-29    1.546929
# 2001-12-30   -0.446863
# 2001-12-31   -0.861941
# Freq: D, Length: 365, dtype: float64

# %%
print("\nDate range-05 month 2001 year:\n", longer_ts["2001-05"])
# Out:
# Date range-05 month 2001 year:
#  2001-05-01    1.420926
# 2001-05-02    1.921490
# 2001-05-03    2.119669
# 2001-05-04    0.138481
# 2001-05-05    0.147787
# 2001-05-06    0.340961
# 2001-05-07   -0.367366
# 2001-05-08    0.109024
# 2001-05-09   -0.769386
# 2001-05-10   -0.659739
# 2001-05-11   -0.795343
# 2001-05-12   -0.663044
# 2001-05-13    0.446096
# 2001-05-14    0.350265
# 2001-05-15   -1.924155
# 2001-05-16    0.604633
# 2001-05-17    1.325403
# 2001-05-18    0.059273
# 2001-05-19   -0.690740
# 2001-05-20    0.882212
# 2001-05-21    1.091183
# 2001-05-22    0.711948
# 2001-05-23    0.215086
# 2001-05-24    1.789268
# 2001-05-25    0.027604
# 2001-05-26   -0.787719
# 2001-05-27   -2.035063
# 2001-05-28   -1.796253
# 2001-05-29   -0.636044
# 2001-05-30   -0.837522
# 2001-05-31    1.497509
# Freq: D, dtype: float64

# %%
print("\nDate range-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# Date range-first few dates in 2000 year:
#  2000-01-01   -0.547025
# 2000-01-02    0.531503
# 2000-01-03   -1.113049
# 2000-01-04   -0.652512
# 2000-01-05   -0.310414
# Freq: D, dtype: float64

# %%
print("\nDate range-first 15 dates in 02 month 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# Date range-first 15 dates in 02 month 2001 year:
#  2000-02-01    1.281661
# 2000-02-02   -0.878779
# 2000-02-03    0.565297
# 2000-02-04    0.054028
# 2000-02-05    2.423291
# 2000-02-06    0.781962
# 2000-02-07    0.707673
# 2000-02-08   -0.535767
# 2000-02-09   -0.261511
# 2000-02-10   -0.671255
# 2000-02-11   -0.138078
# 2000-02-12    1.126401
# 2000-02-13    0.387880
# 2000-02-14   -0.461181
# 2000-02-15   -0.243294
# Freq: D, dtype: float64

# %%
print("\nDate range-rom 26-9-2001:\n",longer_ts[datetime(2000,9,26):])
# Out:
# Date range-rom 26-9-2001:
#  2000-09-26    1.187996
# 2000-09-27   -1.274866
# 2000-09-28   -1.744764
# 2000-09-29    0.245593
# 2000-09-30    0.858721
#                 ...
# 2002-09-22   -0.419925
# 2002-09-23   -1.493236
# 2002-09-24    2.031439
# 2002-09-25    1.378456
# 2002-09-26   -1.348827
# Freq: D, Length: 731, dtype: float64

# %%
print("\nDate range from 26-9-2001 to 25-9-2002:\n",longer_ts[datetime(2001,9,26):datetime(2002,9,25)])
# Out:
# Date range from 26-9-2001 to 25-9-2002:
#  2001-09-26   -0.078789
# 2001-09-27    2.184688
# 2001-09-28    0.857155
# 2001-09-29    1.105514
# 2001-09-30   -0.352796
#                 ...
# 2002-09-21    0.779297
# 2002-09-22   -0.419925
# 2002-09-23   -1.493236
# 2002-09-24    2.031439
# 2002-09-25    1.378456
# Freq: D, Length: 365, dtype: float64
