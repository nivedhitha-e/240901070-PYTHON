# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedhitha-e/240901070-PYTHON/blob/main/240901070_Data_Aggregation_and_Grouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': ['Sai', 'Poo', 'Sub', 'Yuvi', 'Rithi', 'Sangu'],
'B': ['one', 'two', 'three', 'one', 'three', 'two'],
'C': np.random.randint(5, size=6),
'D': np.random.randint(5, size=6),
'E': np.random.randint(5, size=6)})
print("\nOriginal DataFrame\n",df)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  4  0  3
# 1    Poo    two  0  4  4
# 2    Sub  three  2  4  2
# 3   Yuvi    one  1  3  4
# 4  Rithi  three  3  4  1
# 5  Sangu    two  2  4  3

# %%
#Group by (multi-column): with one column sum
df1 = df.groupby(['A', 'B'], as_index=False)['C'].sum()
print("\nOriginal DataFrame\n",df)

print("\nGroup by (multi-column): with one column sum\n",df1)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  4  0  3
# 1    Poo    two  0  4  4
# 2    Sub  three  2  4  2
# 3   Yuvi    one  1  3  4
# 4  Rithi  three  3  4  1
# 5  Sangu    two  2  4  3
#
# Group by (multi-column): with one column sum
#         A      B  C
# 0    Poo    two  0
# 1  Rithi  three  3
# 2    Sai    one  4
# 3  Sangu    two  2
# 4    Sub  three  2
# 5   Yuvi    one  1

# %%
#Group by (multi-column): with one column sum
df2 = df.groupby(['A', 'B'], as_index=False).sum()
print("\nOriginal DataFrame\n",df)
print("\nGroup by (multi-column): with multi columns sum\n",df2)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  4  0  3
# 1    Poo    two  0  4  4
# 2    Sub  three  2  4  2
# 3   Yuvi    one  1  3  4
# 4  Rithi  three  3  4  1
# 5  Sangu    two  2  4  3
#
# Group by (multi-column): with multi columns sum
#         A      B  C  D  E
# 0    Poo    two  0  4  4
# 1  Rithi  three  3  4  1
# 2    Sai    one  4  0  3
# 3  Sangu    two  2  4  3
# 4    Sub  three  2  4  2
# 5   Yuvi    one  1  3  4

# %%
#combined groupby and aggregate function
df3 = df.groupby(['A', 'B'], as_index=False)['C'].agg('sum')
print("\nOriginal DataFrame\n",df)
print("\nCombined Groupby and Aggregate function\n",df3)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  4  0  3
# 1    Poo    two  0  4  4
# 2    Sub  three  2  4  2
# 3   Yuvi    one  1  3  4
# 4  Rithi  three  3  4  1
# 5  Sangu    two  2  4  3
#
# Combined Groupby and Aggregate function
#         A      B  C
# 0    Poo    two  0
# 1  Rithi  three  3
# 2    Sai    one  4
# 3  Sangu    two  2
# 4    Sub  three  2
# 5   Yuvi    one  1

# %%
#combined groupby and aggregate function – separate column headings

df4 = (df.groupby(['A', 'B']).agg([('average', 'mean'), ('total', 'sum')]))
print("\nOriginal DataFrame\n",df)
print("\nCombined Groupby and Aggregate function-separate column headings\n",df4)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  4  0  3
# 1    Poo    two  0  4  4
# 2    Sub  three  2  4  2
# 3   Yuvi    one  1  3  4
# 4  Rithi  three  3  4  1
# 5  Sangu    two  2  4  3
#
# Combined Groupby and Aggregate function-separate column headings
#                    C             D             E
#             average total average total average total
# A     B
# Poo   two       0.0     0     4.0     4     4.0     4
# Rithi three     3.0     3     4.0     4     1.0     1
# Sai   one       4.0     4     0.0     0     3.0     3
# Sangu two       2.0     2     4.0     4     3.0     3
# Sub   three     2.0     2     4.0     4     2.0     2
# Yuvi  one       1.0     1     3.0     3     4.0     4

# %%
df5 = df.groupby(['A', 'B'], as_index=False).sum()
df6 = (df.groupby(['A', 'B']).agg(['sum']))
print("\nOriginal DataFrame\n",df)
print("\nGroupby-sum function\n",df5)
print("\nGroupby and Aggregate - sum function\n",df6)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    Sai    one  4  0  3
# 1    Poo    two  0  4  4
# 2    Sub  three  2  4  2
# 3   Yuvi    one  1  3  4
# 4  Rithi  three  3  4  1
# 5  Sangu    two  2  4  3
#
# Groupby-sum function
#         A      B  C  D  E
# 0    Poo    two  0  4  4
# 1  Rithi  three  3  4  1
# 2    Sai    one  4  0  3
# 3  Sangu    two  2  4  3
# 4    Sub  three  2  4  2
# 5   Yuvi    one  1  3  4
#
# Groupby and Aggregate - sum function
#                C   D   E
#             sum sum sum
# A     B
# Poo   two     0   4   4
# Rithi three   3   4   1
# Sai   one     4   0   3
# Sangu two     2   4   3
# Sub   three   2   4   2
# Yuvi  one     1   3   4
